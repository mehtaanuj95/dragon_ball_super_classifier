# %% [markdown]
# <a href="https://colab.research.google.com/github/mehtaanuj95/dragon_ball_super_classifier/blob/master/dragon_ball_super_character_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *
import numpy as np

# %%
# uploading the URLs text files for the respective classes from local system

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3347cf01-9679-41ed-af93-b9e06ff3e231" name="files[]" multiple disabled />
#      <output id="result-3347cf01-9679-41ed-af93-b9e06ff3e231">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving beerus.txt to beerus.txt
# Saving gohan.txt to gohan.txt
# Saving goku.txt to goku.txt
# Saving hit.txt to hit.txt
# Saving jiren.txt to jiren.txt
# Saving piccolo.txt to piccolo.txt
# Saving vegeta.txt to vegeta.txt
# Saving whis.txt to whis.txt
# Saving zenoh.txt to zenoh.txt
# ...

# %%
# the ususal imports
import numpy as np
np.random.seed(42)

torch.manual_seed(42)

# %%
folders = ["goku", "jiren", "hit", "vegeta", "zenoh", "whis", "beerus", "gohan", "piccolo"]

for f in folders:
  path = Path('data/dragon_ball')
  dest = path/f

  dest.mkdir(parents = True, exist_ok = True)
  print(dest ,"created")
# Out:
# data/dragon_ball/goku created
# data/dragon_ball/jiren created
# data/dragon_ball/hit created
# data/dragon_ball/vegeta created
# data/dragon_ball/zenoh created
# data/dragon_ball/whis created
# data/dragon_ball/beerus created
# data/dragon_ball/gohan created
# data/dragon_ball/piccolo created

# %%
# !mv beerus.txt  data/dragon_ball/beerus.txt
# !mv goku.txt  data/dragon_ball/goku.txt
# !mv whis.txt  data/dragon_ball/whis.txt
# !mv gohan.txt  data/dragon_ball/gohan.txt
# !mv piccolo.txt  data/dragon_ball/piccolo.txt
# !mv zenoh.txt  data/dragon_ball/zenoh.txt
# !mv vegeta.txt  data/dragon_ball/vegeta.txt
# !mv hit.txt  data/dragon_ball/hit.txt
# !mv jiren.txt  data/dragon_ball/jiren.txt

# %%
file = 'beerus.txt'
download_images(path/file, path/'beerus', max_pics = 250) #, max_workers=0)
print("download_images done for beerus")

file = 'goku.txt'
download_images(path/file, path/'goku', max_pics = 250) #, max_workers=0)
print("download_images done for goku")

file = 'whis.txt'
download_images(path/file, path/'whis', max_pics = 250) #, max_workers=0)
print("download_images done for whis")

file = 'gohan.txt'
download_images(path/file, path/'gohan', max_pics = 250) #, max_workers=0)
print("download_images done for gohan")

file = 'piccolo.txt'
download_images(path/file, path/'piccolo', max_pics = 250) #, max_workers=0)
print("download_images done for frieza")

file = 'zenoh.txt'
download_images(path/file, path/'zenoh', max_pics = 250) #, max_workers=0)
print("download_images done for zenoh")

file = 'vegeta.txt'
download_images(path/file, path/'vegeta', max_pics = 250) #, max_workers=0)
print("download_images done for vegeta")

file = 'hit.txt'
download_images(path/file, path/'hit', max_pics = 250) #, max_workers=0)
print("download_images done for hit")

file = 'jiren.txt'
download_images(path/file, path/'jiren', max_pics = 250) #, max_workers=0)
print("download_images done for jiren")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='26' class='' max='26', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [26/26 00:02<00:00]
#     </div>
# download_images done for beerus
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
# removing images which we cannot open
classes = ["goku", "jiren", "hit", "vegeta", "zenoh", "whis", "beerus", "gohan", "piccolo"]

for c in classes:
  print("#######",c)
  verify_images(path/c, delete=True, max_size=500)
print("####### Images verification done #######")
# Out:
# ####### goku
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='37' class='' max='37', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:01<00:00]
#     </div>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:967: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['beerus',
#  'gohan',
#  'goku',
#  'hit',
#  'jiren',
#  'piccolo',
#  'vegeta',
#  'whis',
#  'zenoh']

# %%
data.show_batch(rows=5, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['beerus',
#   'gohan',
#   'goku',
#   'hit',
#   'jiren',
#   'piccolo',
#   'vegeta',
#   'whis',
#   'zenoh'],
#  9,
#  249,
#  62)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.594526</td>
#       <td>2.276217</td>
#       <td>0.822581</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.232643</td>
#       <td>1.594687</td>
#       <td>0.548387</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.841066</td>
#       <td>1.195540</td>
#       <td>0.435484</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.525412</td>
#       <td>0.938726</td>
#       <td>0.274194</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.317538</td>
#       <td>0.832614</td>
#       <td>0.241935</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d81c6bd29d71> in <module>()
# ----> 1 learn.lr_find()
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, wd)
#      30     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      31     epochs = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 32     learn.fit(epochs, start_lr, callbacks=[cb], wd=wd)
#      33
#      34 def to_fp16(learn:Learner, loss_scale:float=None, max_noskip:int=1000, dynamic:bool=True, clip:float=None,
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     197         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# ...

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.482798</td>
#       <td>0.722857</td>
#       <td>0.241935</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.448074</td>
#       <td>0.572121</td>
#       <td>0.209677</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.408250</td>
#       <td>0.493148</td>
#       <td>0.145161</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.364692</td>
#       <td>0.470818</td>
#       <td>0.145161</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.341193</td>
#       <td>0.461435</td>
#       <td>0.145161</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.118455</td>
#       <td>0.559192</td>
#       <td>0.161290</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.133932</td>
#       <td>0.548662</td>
#       <td>0.145161</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.120702</td>
#       <td>0.530809</td>
#       <td>0.129032</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.121034</td>
#       <td>0.518499</td>
#       <td>0.129032</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-3')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(10)

# %%
learn.load('stage-3')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (249 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# vegeta,vegeta,vegeta,vegeta,vegeta
# Path: data/dragon_ball;
#
# Valid: LabelList (62 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# piccolo,vegeta,goku,goku,vegeta
# Path: data/dragon_ball;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.135040</td>
#       <td>0.416076</td>
#       <td>0.096774</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(5)
